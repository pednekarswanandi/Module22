# %% [markdown]
# <a href="https://colab.research.google.com/github/pednekarswanandi/Module22/blob/main/Module22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install "dask[complete]"
# Out:
# ...
#      |████████████████████████████████| 837 kB 6.7 MB/s
# ...
#      |████████████████████████████████| 140 kB 27.6 MB/s
# ...
#      |████████████████████████████████| 830 kB 12.8 MB/s
# ...
#      |████████████████████████████████| 822 kB 32.0 MB/s
# ...
#      |████████████████████████████████| 802 kB 21.6 MB/s
# ...
#      |████████████████████████████████| 802 kB 9.9 MB/s
# ...
#      |████████████████████████████████| 793 kB 57.4 MB/s
# ...
#      |████████████████████████████████| 793 kB 72.0 MB/s
# ...
#      |████████████████████████████████| 791 kB 57.7 MB/s
# ...
#      |████████████████████████████████| 786 kB 44.6 MB/s
# ...
#      |████████████████████████████████| 779 kB 50.9 MB/s
# ...
#      |████████████████████████████████| 778 kB 45.6 MB/s
# ...
#      |████████████████████████████████| 776 kB 56.4 MB/s
# ...
#      |████████████████████████████████| 769 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 766 kB 41.7 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 55.2 MB/s
# ...

# %%
from google.colab import files
uploaded = files.upload()
import dask.dataframe as dd
# %time df = dd.read_csv("dataset.csv", encoding = 'ISO-8859-1')
# Out:
#      <input type="file" id="files-57cf1ab9-26bf-4bcf-86bb-ad96a942b038" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57cf1ab9-26bf-4bcf-86bb-ad96a942b038">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset.csv to dataset.csv
# CPU times: user 5.15 ms, sys: 2.2 ms, total: 7.35 ms
# Wall time: 16.7 ms

# %%
import dask.array as da
x = da.ones((50, 50), chunks=(5, 5))
 
y = x + x.T
 
y.visualize(filename='transpose.svg')

# %%
from dask import delayed

# %%
@delayed
def Numerator(x,y):
 sum = 0
 for i in range(1, y+1):
   sum = sum + (i * x)
 return sum

# %%
@delayed
def Denominator(y):
 factorial = 1
 for i in range(y,1, -1):
   factorial = i* factorial
 return factorial

# %%
def Divide(numerator, denominator):
 return numerator / denominator

# %%
numerator = delayed(Numerator)(1500,10)
denominator = delayed(Denominator)(10)
result = delayed(Divide)(numerator, denominator)
result.compute()
# Out:
# 0.02273478835978836
